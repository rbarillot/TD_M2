# %%
from __future__ import print_function
from ipywidgets import interact, interactive, fixed, interact_manual
import ipywidgets as widgets

# %% [markdown]
# Presentation TD
# ![caption](files/Luzerne.png)

# %% [markdown]
# Loading and visualisation of the MTG

# %%
from openalea.mtg import MTG

g = MTG(r'MTG\luzerne.mtg')
g.display()
g.property_names()
# Out:
# MTG : nb_vertices=57, nb_scales=4
# /P1			(id=1)
# ^/A1			(id=2)
# ^/S1			(id=3)
# 	+A2			(id=4)
# 	^/S1			(id=5)
# 		+T1			(id=6)
# 		^<U1			(id=7)
# 	^<S2			(id=8)
# 		+T1			(id=9)
# 		^<U1			(id=10)
# 	^<S3			(id=11)
# 		+T1			(id=12)
# 		^<U1			(id=13)
# 	^<S4			(id=14)
# 		+T1			(id=15)
# 		^<U1			(id=16)
# 	+A3			(id=17)
# 	^/S1			(id=18)
# 		+T1			(id=19)
# 		^<U1			(id=20)
# 	^<S2			(id=21)
# 		+T1			(id=22)
# 		^<U1			(id=23)
# 	^<S3			(id=24)
# 		+T1			(id=25)
# 		^<U1			(id=26)
# ^<S2			(id=27)
# 	+T1			(id=28)
# 	^<U1			(id=29)
# ^<S3			(id=30)
# 	+T1			(id=31)
# 	^<U1			(id=32)
# ^<S4			(id=33)
# 	+T1			(id=34)
# 	^<U1			(id=35)
# ^<S5			(id=36)
# 	+T1			(id=37)
# 	^<U1			(id=38)
# ^<S6			(id=39)
# 	+T1			(id=40)
# 	^<U1			(id=41)
# ^<S7			(id=42)
# 	+T1			(id=43)
# 	^<U1			(id=44)
# ^<S8			(id=45)
# 	+T1			(id=46)
# 	^<U1			(id=47)
# ^<S9			(id=48)
# 	+T1			(id=49)
# 	^<U1			(id=50)
# ^<S10			(id=51)
# 	+T1			(id=52)
# 	^<U1			(id=53)
# ^<S11			(id=54)
# 	+T1			(id=55)
# 	^<U1			(id=56)
# ['AA',
#  'index',
#  'BB',
#  'CC',
#  'XX',
#  'label',
#  'YY',
#  'Flargeur',
#  'edge_type',
#  'ZZ',
#  '_line']

# %% [markdown]
# Load Lsystem from MTG + visualisation of lstring

# %%
from openalea.lpy import Lsystem, Lstring
from openalea.plantgl.all import Viewer
lsys = Lsystem('TD_lsystem_Luzerne.lpy')
print ('Structure of lstring \n', lsys)
# Out:
# Structure of lstring
#  Lsystem:
# Axiom: [P[A[E(0.24062418831,72.9105966503,8.13010235416)[A[E(0.422610932182,67.3440669917,137.489552922)[F(2.38046214001,29.9935781488,100.056276317)L(0.650615093585,23.5545399214,124.755912554)]E(0.30886890423,29.0546040991,90.0)[F(3.77307566847,43.140700393,104.944822835)L(0.764264352171,5.25516262294,86.9872124958)]E(1.26388290597,64.4198664898,166.218402764)[F(4.65395530705,48.5816961386,158.26770481)L(0.764852927039,27.2326260667,160.232831323)]E(0.370270171631,30.8731322631,65.8544580396)[F(3.02933986208,55.615094139,71.2473329207)L(1.32668760452,0.86377455719,40.4139011038)]]][A[E(0.668580586018,48.4047392115,22.5205656029)[F(3.72844471596,40.0682785089,51.4029128807)L(0.766159252375,15.9080566584,71.8109543003)]E(1.29634100452,51.8902496194,18.2084844706)[F(3.9013459216,46.5013581285,34.9920201986)L(0.8358827669,11.7345535893,63.1218602479)]E(0.346698716467,11.6483459172,103.62699486)[F(3.08635707591,47.0757623596,26.5650511771)L(1.22658061292,34.7985097369,60.8901444431)]]E(2.46296569201,71.8187359045,32.2424678391)[F(3.8615281949,27.1150100043,59.7795601801)L(0.914385039248,46.2030098329,58.5704343852)]E(3.49894269744,74.396917343,75.225449725)[F(3.54021185807,40.3048204929,113.811654251)L(1.58874164042,2.16433206622,116.565051177)]E(4.36382859425,79.4456792112,43.4792303389)[F(3.20889389042,30.5282543185,86.8891593465)L(1.84312235079,10.3140805267,86.5222134802)]E(3.6406730147,77.9158483027,70.8518625421)[F(2.90055167167,34.430745236,54.1839192508)L(2.17678662252,7.39043075221,50.2623953996)]E(3.06654528745,86.2558384553,177.137594774)[F(2.96438863849,46.773287595,124.159694546)L(2.6207250905,3.50018750869,124.722859419)]E(3.33402159561,81.8077958499,30.3432488842)[F(2.98404088444,42.0849812168,14.9147517395)L(2.31898684774,22.8363596917,9.15380945384)]E(3.66766955982,77.4473375683,70.2011236455)[F(2.85525830705,53.6615992466,161.029592192)L(2.70194374479,6.80169005413,164.875992692)]E(1.98891930455,73.805509671,27.9509690279)[F(2.76161184818,19.6795892809,0.881403996582)L(3.26297410348,43.5948909618,20.0452494254)]E(1.02537797909,65.0916458066,47.8155566842)[F(2.75029089371,42.5545696252,153.940858673)L(2.9292661197,17.6878098189,150.127794958)]E(1.17834629884,40.1635526762,60.0183606312)[F(1.10040901487,29.3883516031,16.355817101)L(3.04062493577,36.7669179412,11.1254056418)]]]]]
# module E
# derivation length: 1
# production:
# interpretation:
# maximum depth:1
# E(length,inclination,azimut) :
#
#   produce ;(7) EulerAngles(azimut,inclination,0) F(length)
#
# L(length,inclination,azimut) :
#
#   lf, la, pe, br, crois = 21./21., 6.5/21., 17./21., 3.6/21., 10./21. #leaf Trudeau
#   alpha = 3.14/8 #degre
#   leaf = mesh_leaflet(lf, la, alpha, 10)
#   inclination *= inclination_factor
#   produce ;(7) EulerAngles(azimut+90, 90, 0) +(inclination) @g(leaf, length*scaling_Lmax) EulerAngles(azimut, 90, 0) +(inclination) @g(leaf, length*scaling_Lmax) EulerAngles(azimut+180, 90, 0) +(inclination) @g(leaf, length*scaling_Lmax)
#
# F(length,inclination,azimut) :
#
#   produce ;(7) EulerAngles(azimut,inclination,0) F(length)
#
# endlsystem

# %% [markdown]
# Lsystem interpretation, plantgl

# %%
def run_lsystem(scaling_Lmax=1, inclination_factor=1):
    lsys.scaling_Lmax = scaling_Lmax
    lsys.inclination_factor = inclination_factor
    lstring = lsys.animate()
    interpretedstring = lsys.interpret(lstring)
    scene = lsys.sceneInterpretation(interpretedstring)
    Viewer.display(scene)
    scene.save(r'plante.bgeom')
    return lstring

interact(run_lsystem, scaling_Lmax = (0.5, 2, 0.5), inclination_factor = (0.5, 2, 0.5));
# Out:
# aW50ZXJhY3RpdmUoY2hpbGRyZW49KEZsb2F0U2xpZGVyKHZhbHVlPTEuMCwgZGVzY3JpcHRpb249dSdzY2FsaW5nX0xtYXgnLCBtYXg9Mi4wLCBtaW49MC41LCBzdGVwPTAuNSksIEZsb2F0U2zigKY=

# %% [markdown]
# Fetuque

# %%
from openalea.mtg import MTG

g = MTG(r'MTG\Fet-LD-F2.mtg')
g.display()
# Out:
# MTG : nb_vertices=386, nb_scales=4
# /P1			(id=1)
# ^/A0			(id=2)
# ^/E1			(id=3)
# 	+A1			(id=4)
# 	^/E1			(id=5)
# 		+F1			(id=6)
# 		^<L1			(id=7)
# 		^<L2			(id=8)
# 		^<L3			(id=9)
# 		^<L4			(id=10)
# 		^<L5			(id=11)
# 	+A2			(id=12)
# 	^/E1			(id=13)
# 		+F1			(id=14)
# 		^<L1			(id=15)
# 		^<L2			(id=16)
# 		^<L3			(id=17)
# 		^<L4			(id=18)
# 	^<E2			(id=19)
# 		+F1			(id=20)
# 		^<L1			(id=21)
# 		^<L2			(id=22)
# 		^<L3			(id=23)
# 	+A3			(id=24)
# 	^/E1			(id=25)
# 		+F1			(id=26)
# 		^<L1			(id=27)
# 		^<L2			(id=28)
# 		^<L3			(id=29)
# 		^<L4			(id=30)
# 	^<E2			(id=31)
# 		+F1			(id=32)
# 		^<L1			(id=33)
# 		^<L2			(id=34)
# 		^<L3			(id=35)
# 		^<L4			(id=36)
# 	+A4			(id=37)
# 	^/E1			(id=38)
# 		+F1			(id=39)
# 		^<L1			(id=40)
# 		^<L2			(id=41)
# 		^<L3			(id=42)
# 	^<E2			(id=43)
# 		+F1			(id=44)
# 		^<L1			(id=45)
# 		^<L2			(id=46)
# 		^<L3			(id=47)
# 		^<L4			(id=48)
# 		^<L5			(id=49)
# 	^<E3			(id=50)
# 		+F1			(id=51)
# 		^<L1			(id=52)
# 		^<L2			(id=53)
# 		^<L3			(id=54)
# 	^<E4			(id=55)
# 		+F1			(id=56)
# 		^<L1			(id=57)
# 		^<L2			(id=58)
# 	+A5			(id=59)
# 	^/E1			(id=60)
# 		+F1			(id=61)
# 		^<L1			(id=62)
# 		^<L2			(id=63)
# 		^<L3			(id=64)
# 		^<L4			(id=65)
# 	^<E2			(id=66)
# 		+F1			(id=67)
# 		^<L1			(id=68)
# 		^<L2			(id=69)
# 		^<L3			(id=70)
# 		^<L4			(id=71)
# 	^<E3			(id=72)
# 		+F1			(id=73)
# 		^<L1			(id=74)
# 		^<L2			(id=75)
# 		^<L3			(id=76)
# 		^<L4			(id=77)
# 	+A6			(id=78)
# 	^/E1			(id=79)
# 		+F1			(id=80)
# 		^<L1			(id=81)
# 		^<L2			(id=82)
# 		^<L3			(id=83)
# 		^<L4			(id=84)
# 	^<E2			(id=85)
# 		+F1			(id=86)
# 		^<L1			(id=87)
# 		^<L2			(id=88)
# 		^<L3			(id=89)
# 		^<L4			(id=90)
# 	^<E3			(id=91)
# 		+F1			(id=92)
# 		^<L1			(id=93)
# 		^<L2			(id=94)
# 	+A7			(id=95)
# 	^/E1			(id=96)
# 		+F1			(id=97)
# 		^<L1			(id=98)
# 		^<L2			(id=99)
# 		^<L3			(id=100)
# 		^<L4			(id=101)
# 		^<L5			(id=102)
# 	^<E2			(id=103)
# 		+F1			(id=104)
# 		^<L1			(id=105)
# 		^<L2			(id=106)
# 		^<L3			(id=107)
# 	+A8			(id=108)
# 	^/E1			(id=109)
# 		+F1			(id=110)
# 		^<L1			(id=111)
# 		^<L2			(id=112)
# 		^<L3			(id=113)
# 	^<E2			(id=114)
# 		+F1			(id=115)
# 		^<L1			(id=116)
# 		^<L2			(id=117)
# 		^<L3			(id=118)
# 		^<L4			(id=119)
# 	^<E3			(id=120)
# 		+F1			(id=121)
# 		^<L1			(id=122)
# 		^<L2			(id=123)
# 	+A9			(id=124)
# 	^/E1			(id=125)
# 		+F1			(id=126)
# 		^<L1			(id=127)
# 		^<L2			(id=128)
# 		^<L3			(id=129)
# 	^<E2			(id=130)
# 		+F1			(id=131)
# 		^<L1			(id=132)
# 		^<L2			(id=133)
# 		^<L3			(id=134)
# 	^<E3			(id=135)
# 		+F1			(id=136)
# 		^<L1			(id=137)
# 		^<L2			(id=138)
# 		^<L3			(id=139)
# 	+A10			(id=140)
# 	^/E1			(id=141)
# 		+F1			(id=142)
# 		^<L1			(id=143)
# 		^<L2			(id=144)
# 		^<L3			(id=145)
# 	^<E2			(id=146)
# 		+F1			(id=147)
# 		^<L1			(id=148)
# 		^<L2			(id=149)
# 		^<L3			(id=150)
# 	^<E3			(id=151)
# 		+F1			(id=152)
# 		^<L1			(id=153)
# 		^<L2			(id=154)
# 		^<L3			(id=155)
# 		^<L4			(id=156)
# 		^<L5			(id=157)
# 	^<E4			(id=158)
# 		+F1			(id=159)
# 		^<L1			(id=160)
# 		^<L2			(id=161)
# 		^<L3			(id=162)
# 	+A11			(id=163)
# 	^/E1			(id=164)
# 		+F1			(id=165)
# 		^<L1			(id=166)
# 		^<L2			(id=167)
# 		^<L3			(id=168)
# 		^<L4			(id=169)
# 	^<E2			(id=170)
# 		+F1			(id=171)
# 		^<L1			(id=172)
# 		^<L2			(id=173)
# 		^<L3			(id=174)
# 	^<E3			(id=175)
# 		+F1			(id=176)
# 		^<L1			(id=177)
# 		^<L2			(id=178)
# 		^<L3			(id=179)
# 	+A12			(id=180)
# 	^/E1			(id=181)
# 		+F1			(id=182)
# 		^<L1			(id=183)
# 		^<L2			(id=184)
# 		^<L3			(id=185)
# 	^<E2			(id=186)
# 		+F1			(id=187)
# 		^<L1			(id=188)
# 		^<L2			(id=189)
# 		^<L3			(id=190)
# 		^<L4			(id=191)
# 	+A13			(id=192)
# 	^/E1			(id=193)
# 		+F1			(id=194)
# 		^<L1			(id=195)
# 		^<L2			(id=196)
# 		^<L3			(id=197)
# 		^<L4			(id=198)
# 	^<E2			(id=199)
# 		+F1			(id=200)
# 		^<L1			(id=201)
# 		^<L2			(id=202)
# 		^<L3			(id=203)
# 	+A14			(id=204)
# 	^/E1			(id=205)
# 		+F1			(id=206)
# 		^<L1			(id=207)
# 		^<L2			(id=208)
# 		^<L3			(id=209)
# 	^<E2			(id=210)
# 		+F1			(id=211)
# 		^<L1			(id=212)
# 		^<L2			(id=213)
# 		^<L3			(id=214)
# 		^<L4			(id=215)
# 	^<E3			(id=216)
# 		+F1			(id=217)
# 		^<L1			(id=218)
# 		^<L2			(id=219)
# 		^<L3			(id=220)
# 	+A15			(id=221)
# 	^/E1			(id=222)
# 		+F1			(id=223)
# 		^<L1			(id=224)
# 		^<L2			(id=225)
# 		^<L3			(id=226)
# 	^<E2			(id=227)
# 		+F1			(id=228)
# 		^<L1			(id=229)
# 		^<L2			(id=230)
# 		^<L3			(id=231)
# 	+A16			(id=232)
# 	^/E1			(id=233)
# 		+F1			(id=234)
# 		^<L1			(id=235)
# 		^<L2			(id=236)
# 		^<L3			(id=237)
# 	^<E2			(id=238)
# 		+F1			(id=239)
# 		^<L1			(id=240)
# 		^<L2			(id=241)
# 		^<L3			(id=242)
# 	+A17			(id=243)
# 	^/E1			(id=244)
# 		+F1			(id=245)
# 		^<L1			(id=246)
# 		^<L2			(id=247)
# 		^<L3			(id=248)
# 	^<E2			(id=249)
# 		+F1			(id=250)
# 		^<L1			(id=251)
# 		^<L2			(id=252)
# 		^<L3			(id=253)
# 		^<L4			(id=254)
# 		^<L5			(id=255)
# 	^<E3			(id=256)
# 		+F1			(id=257)
# 		^<L1			(id=258)
# 		^<L2			(id=259)
# 	+A18			(id=260)
# 	^/E1			(id=261)
# 		+F1			(id=262)
# 		^<L1			(id=263)
# 		^<L2			(id=264)
# 		^<L3			(id=265)
# 		^<L4			(id=266)
# 		^<L5			(id=267)
# 	^<E2			(id=268)
# 		+F1			(id=269)
# 		^<L1			(id=270)
# 		^<L2			(id=271)
# 		^<L3			(id=272)
# 		^<L4			(id=273)
# 	^<E3			(id=274)
# 		+F1			(id=275)
# 		^<L1			(id=276)
# 		^<L2			(id=277)
# 		^<L3			(id=278)
# 	^<E4			(id=279)
# 		+F1			(id=280)
# 		^<L1			(id=281)
# 		^<L2			(id=282)
# 	+A19			(id=283)
# 	^/E1			(id=284)
# 		+F1			(id=285)
# 		^<L1			(id=286)
# 		^<L2			(id=287)
# 		^<L3			(id=288)
# 	^<E2			(id=289)
# 		+F1			(id=290)
# 		^<L1			(id=291)
# 		^<L2			(id=292)
# 		^<L3			(id=293)
# 		^<L4			(id=294)
# 	^<E3			(id=295)
# 		+F1			(id=296)
# 		^<L1			(id=297)
# 		^<L2			(id=298)
# 		^<L3			(id=299)
# 	+A20			(id=300)
# 	^/E1			(id=301)
# 		+F1			(id=302)
# 		^<L1			(id=303)
# 		^<L2			(id=304)
# 		^<L3			(id=305)
# 	^<E2			(id=306)
# 		+F1			(id=307)
# 		^<L1			(id=308)
# 		^<L2			(id=309)
# 		^<L3			(id=310)
# 	+A21			(id=311)
# 	^/E1			(id=312)
# 		+F1			(id=313)
# 		^<L1			(id=314)
# 		^<L2			(id=315)
# 		^<L3			(id=316)
# 		^<L4			(id=317)
# 	^<E2			(id=318)
# 		+F1			(id=319)
# 		^<L1			(id=320)
# 		^<L2			(id=321)
# 		^<L3			(id=322)
# 	^<E3			(id=323)
# 		+F1			(id=324)
# 		^<L1			(id=325)
# 		^<L2			(id=326)
# 	+A22			(id=327)
# 	^/E1			(id=328)
# 		+F1			(id=329)
# 		^<L1			(id=330)
# 		^<L2			(id=331)
# 		^<L3			(id=332)
# 	^<E2			(id=333)
# 		+F1			(id=334)
# 		^<L1			(id=335)
# 		^<L2			(id=336)
# 		^<L3			(id=337)
# 		^<L4			(id=338)
# 		^<L5			(id=339)
# 	^<E3			(id=340)
# 		+F1			(id=341)
# 		^<L1			(id=342)
# 		^<L2			(id=343)
# 		^<L3			(id=344)
# 	+A23			(id=345)
# 	^/E1			(id=346)
# 		+F1			(id=347)
# 		^<L1			(id=348)
# 		^<L2			(id=349)
# 		^<L3			(id=350)
# 		^<L4			(id=351)
# 	^<E2			(id=352)
# 		+F1			(id=353)
# 		^<L1			(id=354)
# 		^<L2			(id=355)
# 		^<L3			(id=356)
# 		^<L4			(id=357)
# 	+A24			(id=358)
# 	^/E1			(id=359)
# 		+F1			(id=360)
# 		^<L1			(id=361)
# 		^<L2			(id=362)
# 		^<L3			(id=363)
# 		^<L4			(id=364)
# 	^<E2			(id=365)
# 		+F1			(id=366)
# 		^<L1			(id=367)
# 		^<L2			(id=368)
# 		^<L3			(id=369)
# 	^<E3			(id=370)
# 		+F1			(id=371)
# 		^<L1			(id=372)
# 		^<L2			(id=373)
# 		^<L3			(id=374)
# 		^<L4			(id=375)
# 	^<E4			(id=376)
# 		+F1			(id=377)
# 		^<L1			(id=378)
# 		^<L2			(id=379)
# 	+A25			(id=380)
# 	^/E1			(id=381)
# 		+F1			(id=382)
# 		^<L1			(id=383)
# 		^<L2			(id=384)
# 		^<L3			(id=385)

# %%
from openalea.lpy import Lsystem, Lstring
from openalea.plantgl.all import Viewer
lsys = Lsystem('TD_lsystem_Fetuque.lpy')
lstring = lsys.animate()
# Out:
# TD_lsystem_Fetuque.lpy:48: RuntimeWarning: invalid value encountered in double_scalars
#   curr_azimut = arccos(x_projection / (curr_length * cos(curr_inclination)))
# TD_lsystem_Fetuque.lpy:52: ComplexWarning: Casting complex values to real discards the imaginary part
#   return length, inclination, azimut, F_to_Ls_map, espece

# %% [markdown]
# Caribu

# %%
from alinea.caribu.CaribuScene import CaribuScene
from openalea.plantgl.all import Scene, Viewer


interpretedstring = lsys.interpret(lstring)
scene = lsys.sceneInterpretation(lstring)

c_scene = CaribuScene(scene=scene)
Viewer.display(scene)
raw, aggregated = c_scene.run()

# Visualisation
viewmaponcan, _ = c_scene.plot(raw['default_band']['Eabs'], display=False)
Viewer.display(viewmaponcan)

# Graph
import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline  

graph = {'Tige':0, 'Feuilles':0}
for vid, Eabs in aggregated['default_band']['Eabs'].items():
    if lstring[vid].name == 'F':
        graph['Feuilles'] += Eabs / sum(aggregated['default_band']['Eabs'].values())
    else:
        graph['Tige'] += Eabs / sum(aggregated['default_band']['Eabs'].values())

xindex = [1, 2]
LABELS = graph.keys()
plt.bar(xindex, graph.values(), align='center')
plt.xticks(xindex, LABELS)
# Out:
# ([<matplotlib.axis.XTick at 0x10c87e10>,
#   <matplotlib.axis.XTick at 0x10f3e0f0>],
#  <a list of 2 Text xticklabel objects>)

# %% [markdown]
# Caribu sur de l'association

# %%
def Run_Asso(distance=10.):
    lsys_fet.distance = distance
    lsys_fet_str = lsys_fet.animate()
    print (lsys_fet.distance)
    scene_fet = lsys_fet.sceneInterpretation(lsys_fet_str)
    scene_luz = lsys_luz.sceneInterpretation(lsys_luz_str)
    Viewer.display(scene_fet+scene_luz)
    return

# %%
def Calcul_Caribu(scene):
    from alinea.caribu.CaribuScene import CaribuScene
    from openalea.plantgl.all import Scene, Viewer


    c_scene = CaribuScene(scene=scene)
    Viewer.display(scene)
    raw, aggregated = c_scene.run()

    # Visualisation
    viewmaponcan, _ = c_scene.plot(raw['default_band']['Eabs'], display=False)
    Viewer.display(viewmaponcan)

    # Graph
    import matplotlib
    import matplotlib.pyplot as plt
    # %matplotlib inline  

    graph = {'luzerne':0, 'fetuque':0}
    eabs_total = sum(eabs*area for (eabs, area) in zip(aggregated['default_band']['Eabs'].values(), aggregated['default_band']['area'].values()))
    for vid, Eabs in aggregated['default_band']['Eabs'].items():
        if 'luzerne' in lsys_asso_str[vid] :
            graph['luzerne'] += Eabs * aggregated['default_band']['area'][vid] / eabs_total
        elif 'fetuque' in lsys_asso_str[vid]:
            graph['fetuque'] +=  Eabs * aggregated['default_band']['area'][vid] / eabs_total
        else:
            print ('vid',vid,lsys_asso_str[vid])

    xindex = [1, 2]
    LABELS = graph.keys()
    plt.bar(xindex, graph.values(), align='center')
    plt.xticks(xindex, LABELS)
    return

# %%
def Run_Asso2(distance=0):
    scene_out = Scene()
    for i in range(len(scene_fet)):
        scene_out+=Shape(Translated(distance,0,0,scene_fet[i].geometry),scene_fet[i].appearance)
    #Viewer.display(scene_out+scene_luz)
    Calcul_Caribu(scene_out+scene_luz)
    return

# %%
from openalea.lpy import Lsystem, Lstring
from openalea.plantgl.all import Viewer,Translated,Shape
lsys_luz = Lsystem('TD_lsystem_Luzerne.lpy')
lsys_fet = Lsystem('TD_lsystem_Fetuque.lpy')
lsys_luz_str = lsys_luz.animate()
lsys_fet_str = lsys_fet.animate()
lsys_asso_str = lsys_luz_str + lsys_fet_str

scene_asso = lsys_fet.sceneInterpretation(lsys_asso_str)
#print('fetuque' in lsys_asso_str[1024])

scene_fet = lsys_fet.sceneInterpretation(lsys_fet_str)
scene_luz = lsys_luz.sceneInterpretation(lsys_luz_str)
#print (interpretedstring)
#scene = lsys.sceneInterpretation(interpretedstring)
#scene=Scene()
#scene.add(scene_fet)
#scene.add(scene_luz)
Viewer.display(scene_asso)
interact(Run_Asso3,distance = (0,100,1));
# Out:
# TD_lsystem_Fetuque.lpy:47: RuntimeWarning: invalid value encountered in double_scalars
#   x_projection = distal_position[0] - basal_position[0]
# TD_lsystem_Fetuque.lpy:51: ComplexWarning: Casting complex values to real discards the imaginary part
# aW50ZXJhY3RpdmUoY2hpbGRyZW49KEludFNsaWRlcih2YWx1ZT0wLCBkZXNjcmlwdGlvbj11J2Rpc3RhbmNlJyksIE91dHB1dCgpKSwgX2RvbV9jbGFzc2VzPSh1J3dpZGdldC1pbnRlcmFjdCfigKY=

# %% [markdown]
# test avec ComposedLsystem : ne marche pas car fait pour production et interpretation separees

# %%
from openalea.lpy import Lsystem, Lstring
from openalea.lpy.composition import *
from openalea.plantgl.all import Viewer,Translated,Shape
lsys_luz = Lsystem('TD_lsystem_Luzerne.lpy')
lsys_fet = Lsystem('TD_lsystem_Fetuque.lpy')

lsys_ass = ComposedLsystem([lsys_luz,lsys_fet],[lsys_luz,lsys_fet])
print(lsys_ass.axiom)
lsys_ass_str = lsys_ass.animate(lsys_ass.axiom)
print (lsys_ass_str)
##lsys_luz_str = lsys_luz.animate()
##lsys_fet_str = lsys_fet.animate()
#interpretedstring = lsys.interpret(lstring)


scene_fet = lsys_fet.sceneInterpretation(lsys_fet_str)
scene_luz = lsys_luz.sceneInterpretation(lsys_luz_str)
#print (interpretedstring)
#scene = lsys.sceneInterpretation(interpretedstring)
#scene=Scene()
#scene.add(scene_fet)
#scene.add(scene_luz)
##Viewer.display(scene_fet+scene_luz)
#interact(Run_Asso2,distance = (0,100,1));
# Out:
# [P[A[S(0.24062418831,72.9105966503,8.13010235416,luzerne)[A[S(0.422610932182,67.3440669917,137.489552922,luzerne)[T(2.38046214001,29.9935781488,100.056276317,luzerne)U(0.650615093585,23.5545399214,124.755912554,luzerne)]S(0.30886890423,29.0546040991,90.0,luzerne)[T(3.77307566847,43.140700393,104.944822835,luzerne)U(0.764264352171,5.25516262294,86.9872124958,luzerne)]S(1.26388290597,64.4198664898,166.218402764,luzerne)[T(4.65395530705,48.5816961386,158.26770481,luzerne)U(0.764852927039,27.2326260667,160.232831323,luzerne)]S(0.370270171631,30.8731322631,65.8544580396,luzerne)[T(3.02933986208,55.615094139,71.2473329207,luzerne)U(1.32668760452,0.86377455719,40.4139011038,luzerne)]]][A[S(0.668580586018,48.4047392115,22.5205656029,luzerne)[T(3.72844471596,40.0682785089,51.4029128807,luzerne)U(0.766159252375,15.9080566584,71.8109543003,luzerne)]S(1.29634100452,51.8902496194,18.2084844706,luzerne)[T(3.9013459216,46.5013581285,34.9920201986,luzerne)U(0.8358827669,11.7345535893,63.1218602479,luzerne)]S(0.346698716467,11.6483459172,103.62699486,luzerne)[T(3.08635707591,47.0757623596,26.5650511771,luzerne)U(1.22658061292,34.7985097369,60.8901444431,luzerne)]]S(2.46296569201,71.8187359045,32.2424678391,luzerne)[T(3.8615281949,27.1150100043,59.7795601801,luzerne)U(0.914385039248,46.2030098329,58.5704343852,luzerne)]S(3.49894269744,74.396917343,75.225449725,luzerne)[T(3.54021185807,40.3048204929,113.811654251,luzerne)U(1.58874164042,2.16433206622,116.565051177,luzerne)]S(4.36382859425,79.4456792112,43.4792303389,luzerne)[T(3.20889389042,30.5282543185,86.8891593465,luzerne)U(1.84312235079,10.3140805267,86.5222134802,luzerne)]S(3.6406730147,77.9158483027,70.8518625421,luzerne)[T(2.90055167167,34.430745236,54.1839192508,luzerne)U(2.17678662252,7.39043075221,50.2623953996,luzerne)]S(3.06654528745,86.2558384553,177.137594774,luzerne)[T(2.96438863849,46.773287595,124.159694546,luzerne)U(2.6207250905,3.50018750869,124.722859419,luzerne)]S(3.33402159561,81.8077958499,30.3432488842,luzerne)[T(2.98404088444,42.0849812168,14.9147517395,luzerne)U(2.31898684774,22.8363596917,9.15380945384,luzerne)]S(3.66766955982,77.4473375683,70.2011236455,luzerne)[T(2.85525830705,53.6615992466,161.029592192,luzerne)U(2.70194374479,6.80169005413,164.875992692,luzerne)]S(1.98891930455,73.805509671,27.9509690279,luzerne)[T(2.76161184818,19.6795892809,0.881403996582,luzerne)U(3.26297410348,43.5948909618,20.0452494254,luzerne)]S(1.02537797909,65.0916458066,47.8155566842,luzerne)[T(2.75029089371,42.5545696252,153.940858673,luzerne)U(2.9292661197,17.6878098189,150.127794958,luzerne)]S(1.17834629884,40.1635526762,60.0183606311,luzerne)[T(1.10040901487,29.3883516031,16.355817101,luzerne)U(3.04062493577,36.7669179412,11.1254056418,luzerne)]]]]]
# C:\Users\dicombes\AppData\Local\conda\conda\envs\py27_64_TD\lib\site-packages\ipykernel_launcher.py:5: Warning: Redeclaration of module 'P'.
#   """
# ---------------------------------------------------------------------------
# ArgumentError                             Traceback (most recent call last)
# <ipython-input-194-11f5ae631da3> in <module>()
#       6 lsys_ass = ComposedLsystem([lsys_luz,lsys_fet],[lsys_fet])
#       7 print(lsys_ass.axiom)
# ----> 8 lsys_ass_str = lsys_fet.animate(lsys_ass.axiom)
#       9 print (lsys_ass_str)
#      10 ##lsys_luz_str = lsys_luz.animate()
#
# ArgumentError: Python argument types in
#     Lsystem.animate(Lsystem, AxialTree)
# did not match C++ signature:
#     animate(class LPY::Lsystem {lvalue}, class LPY::AxialTree, double, unsigned __int64, unsigned __int64)
#     animate(class LPY::Lsystem {lvalue}, double, unsigned __int64, unsigned __int64)
#     animate(class LPY::Lsystem {lvalue}, double, unsigned __int64)
#     animate(class LPY::Lsystem {lvalue}, double)
#     animate(class LPY::Lsystem {lvalue})

# %% [markdown]
# caribu avec renumerotation des indices de la scene pour le fonctionnement de caribu

# %%
def Run_Asso3(distance=0):
    scene_out = Scene()
    for i in range(len(scene_asso)):
        if 'fetuque' in lsys_asso_str[scene_asso[i].id]:
            scene_out+=Shape(Translated(distance,0,0,scene_asso[i].geometry),scene_asso[i].appearance,id = scene_asso[i].id )
        else:
            scene_out+=Shape(scene_asso[i].geometry,scene_asso[i].appearance,id = scene_asso[i].id )
    Calcul_Caribu(scene_out)#scene_out+scene_luz)
    return

# %%
from openalea.lpy import Lsystem, Lstring
from openalea.plantgl.all import Viewer,Translated,Shape
lsys_luz = Lsystem('TD_lsystem_Luzerne.lpy')
lsys_fet = Lsystem('TD_lsystem_Fetuque.lpy')
lsys_luz_str = lsys_luz.animate()
lsys_fet_str = lsys_fet.animate()
lstring = lsys_luz_str + lsys_fet_str
#print (lstring)
scene_fet = lsys_fet.sceneInterpretation(lsys_fet_str)
scene_luz = lsys_luz.sceneInterpretation(lsys_luz_str)

#print (interpretedstring)
#scene = lsys.sceneInterpretation(interpretedstring)
#scene=Scene()
#scene.add(scene_fet)
#scene.add(scene_luz)
Viewer.display(scene_fet+scene_luz)
for shl in scene_luz:
    for shf in scene_fet:
        if shl.id == shf.id:
            print (shl.id)
            
##interact(Run_Asso3,distance = (0,100,1));
# Out:
# TD_lsystem_Fetuque.lpy:48: RuntimeWarning: invalid value encountered in double_scalars
#   curr_azimut = arccos(x_projection / (curr_length * cos(curr_inclination)))
# TD_lsystem_Fetuque.lpy:52: ComplexWarning: Casting complex values to real discards the imaginary part
#   return length, inclination, azimut, F_to_Ls_map, espece
# 9
# 11
# 53
# 53
# 53
# 73
# 73
# 73
# 80
# 82
# 87
# 98
# 98
# 98
